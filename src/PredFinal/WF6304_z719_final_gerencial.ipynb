# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianela-Fontana/dmeyf2026/blob/main/WF6304_z719_final_gerencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow Gerencial, futuro=SEP

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}


# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"
descargar  "gerencial_competencia_2026.csv.gz"

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Sep 20 11:29:59 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  804736 43.0 1473300    78.7 1473300  78.7
# Vcells 1572894 12.1 8388608    64.0 6624357  50.6

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 130003

PARAM$experimento <- 6304
PARAM$dataset <- "gerencial_competencia_2026.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
drift_estandarizar <- function(campos_drift) {

  cat("inicio drift_estandarizar()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_normal") :=
      (get(campo) - mean(get(campo), na.rm = TRUE)) / sd(get(campo), na.rm = TRUE),
      by = list(foto_mes)]
  }
  cat("fin drift_estandarizar()\n")
}

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# ---------------------------------------------------------------------
# division segura
# Evita Inf/NaN cuando el denominador es 0:
# denominador = 0 -> NA
# ---------------------------------------------------------------------
divseg <- function( numerador, denominador )
{
  denominador[ denominador == 0 ] <- NA
  return( numerador / denominador )
}


# ---------------------------------------------------------------------
# VARIABLES BASICAS
# ---------------------------------------------------------------------

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# ---------------------------------------------------------------------
# FE intra-mes basado en Feature Importance del baseline (10 semillas)
#
# Se toman las 10 variables mas importantes del baseline, EXCLUYENDO
# ctrx_quarter_lag1 porque no es intra-mes y proviene del FE historico.
# ---------------------------------------------------------------------

vars_top10 <- c(
  "ctrx_quarter",
  "mcaja_ahorro",
  "cpayroll_trx",
  "mcuentas_saldo",
  "mcuenta_corriente",
  "mprestamos_personales",
  "mtarjeta_visa_consumo",
  "Visa_mpagominimo",
  "cliente_edad",
  "mpasivos_margen"
)

# Variables de alto riesgo como denominadores:
# pueden presentar 0 o NA porque no todos los clientes tienen
# necesariamente esos productos.
vars_alto_riesgo <- c(
  "cpayroll_trx",
  "mcuenta_corriente",
  "mprestamos_personales",
  "Visa_mpagominimo"
)


# ---------------------------------------------------------------------
# A) FLAGS EXPLICITOS
# ---------------------------------------------------------------------
if( atributos_presentes( vars_alto_riesgo ) )
{
  for( v in vars_alto_riesgo )
  {
    nombre_flag <- paste0( "flag_tiene_", v )

    dataset[, (nombre_flag) := as.integer( get(v) > 0 ) ]
  }
}


# ---------------------------------------------------------------------
# B) ESTANDARIZACION DE LAS 10 VARIABLES TOP
#
# IMPORTANTE:
# La media y el desvio estandar se calculan SOLO con el periodo de
# entrenamiento (202005-202104), para evitar leakage de validation/future.
# Luego esos mismos parametros se aplican a todos los registros.
#
# Las variables estandarizadas se llaman z_<variable>.
# ---------------------------------------------------------------------

if( atributos_presentes( vars_top10 ) )
{
  filas_estandarizacion <- dataset[foto_mes %in% c(
    202005, 202006, 202007, 202008, 202009, 202010,
    202011, 202012, 202101, 202102, 202103, 202104
  )]

  for( v in vars_top10 )
  {
    media_v <- mean( filas_estandarizacion[[v]], na.rm = TRUE )
    desvio_v <- sd( filas_estandarizacion[[v]], na.rm = TRUE )

    nombre_z <- paste0( "z_", v )

    if( is.finite(desvio_v) && desvio_v > 0 )
    {
      dataset[, (nombre_z) := (get(v) - media_v) / desvio_v ]
    }
    else
    {
      dataset[, (nombre_z) := NA_real_ ]
    }

    cat(sprintf(
      "Estandarizada %s | media entrenamiento = %.6f | sd entrenamiento = %.6f\n",
      v, media_v, desvio_v
    ))
  }

  rm(filas_estandarizacion)
}

# ---------------------------------------------------------------------
# C) 45 RATIOS UNICOS SOBRE VARIABLES ESTANDARIZADAS
#
# Se genera UNA sola division por cada par de variables:
#   z_A / z_B
# y NO se genera z_B / z_A.
#
# Esto produce 10*9/2 = 45 ratios unicos.
#
# ATENCION: como los z pueden estar cerca de 0, estos ratios pueden
# tomar valores extremos. divseg() convierte denominadores exactamente
# iguales a 0 en NA. LightGBM puede manejar NA nativamente.
# ---------------------------------------------------------------------

vars_z_top10 <- paste0( "z_", vars_top10 )

if( atributos_presentes( vars_z_top10 ) )
{
  n_vars <- length( vars_z_top10 )

  for( i in 1:(n_vars - 1) )
  {
    for( j in (i + 1):n_vars )
    {
      num <- vars_z_top10[i]
      den <- vars_z_top10[j]

      nombre_nueva <- paste0(
        "ratio_",
        vars_top10[i],
        "_sobre_",
        vars_top10[j],
        "_z"
      )

      dataset[, (nombre_nueva) := divseg(
        get(num),
        get(den)
      )]
    }
  }
}
# Out:
# Estandarizada ctrx_quarter | media entrenamiento = 107.457588 | sd entrenamiento = 81.531777
# Estandarizada mcaja_ahorro | media entrenamiento = 70943.618155 | sd entrenamiento = 206132.717886
# Estandarizada cpayroll_trx | media entrenamiento = 0.946460 | sd entrenamiento = 1.369012
# Estandarizada mcuentas_saldo | media entrenamiento = 205587.619505 | sd entrenamiento = 1384991.381001
# Estandarizada mcuenta_corriente | media entrenamiento = 2966.143693 | sd entrenamiento = 67231.668455
# Estandarizada mprestamos_personales | media entrenamiento = 27477.398516 | sd entrenamiento = 89689.700641
# Estandarizada mtarjeta_visa_consumo | media entrenamiento = 27384.640301 | sd entrenamiento = 42853.134924
# Estandarizada Visa_mpagominimo | media entrenamiento = 4926.747559 | sd entrenamiento = 15503.369565
# Estandarizada cliente_edad | media entrenamiento = 46.728670 | sd entrenamiento = 12.971815
# Estandarizada mpasivos_margen | media entrenamiento = 1429.683403 | sd entrenamiento = 4322.040329

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"
#  [2] "foto_mes"
#  [3] "internet"
#  [4] "cliente_edad"
#  [5] "cliente_antiguedad"
#  [6] "mrentabilidad"
#  [7] "mrentabilidad_annual"
#  [8] "mcomisiones"
#  [9] "mactivos_margen"
# [10] "mpasivos_margen"
# [11] "cproductos"
# [12] "mcuenta_corriente"
# [13] "mcaja_ahorro"
# [14] "cdescubierto_preacordado"
# [15] "mcuentas_saldo"
# [16] "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"
# [18] "mtarjeta_master_consumo"
# [19] "mprestamos_personales"
# [20] "cpayroll_trx"
# [21] "mpayroll"
# [22] "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"
# [24] "chomebanking_transacciones"
# [25] "ctrx_quarter"
# [26] "Master_status"
# [27] "Master_fechaalta"
# [28] "Master_mpagominimo"
# [29] "Visa_status"
# [30] "Visa_fechaalta"
# [31] "Visa_mpagominimo"
# [32] "clase_ternaria"
# [33] "kmes"
# [34] "mpayroll_sobre_edad"
# [35] "flag_tiene_cpayroll_trx"
# [36] "flag_tiene_mcuenta_corriente"
# [37] "flag_tiene_mprestamos_personales"
# [38] "flag_tiene_Visa_mpagominimo"
# [39] "z_ctrx_quarter"
# [40] "z_mcaja_ahorro"
# [41] "z_cpayroll_trx"
# [42] "z_mcuentas_saldo"
# [43] "z_mcuenta_corriente"
# [44] "z_mprestamos_personales"
# [45] "z_mtarjeta_visa_consumo"
# [46] "z_Visa_mpagominimo"
# [47] "z_cliente_edad"
# [48] "z_mpasivos_margen"
# [49] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z"
# [50] "ratio_ctrx_quarter_sobre_cpayroll_trx_z"
# [51] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z"
# [52] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z"
# [53] "ratio_ctrx_quarter_sobre_mprestamos_personales_z"
# [54] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z"
# [55] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z"
# [56] "ratio_ctrx_quarter_sobre_cliente_edad_z"
# [57] "ratio_ctrx_quarter_sobre_mpasivos_margen_z"
# [58] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z"
# [59] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z"
# [60] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z"
# [61] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z"
# [62] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z"
# [63] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z"
# [64] "ratio_mcaja_ahorro_sobre_cliente_edad_z"
# [65] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z"
# [66] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z"
# [67] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z"
# [68] "ratio_cpayroll_trx_sobre_mprestamos_personales_z"
# [69] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z"
# [70] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z"
# [71] "ratio_cpayroll_trx_sobre_cliente_edad_z"
# [72] "ratio_cpayroll_trx_sobre_mpasivos_margen_z"
# [73] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z"
# [74] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z"
# [75] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z"
# [76] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z"
# [77] "ratio_mcuentas_saldo_sobre_cliente_edad_z"
# [78] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z"
# [79] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z"
# [80] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z"
# [81] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z"
# [82] "ratio_mcuenta_corriente_sobre_cliente_edad_z"
# [83] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z"
# [84] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z"
# [85] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z"
# [86] "ratio_mprestamos_personales_sobre_cliente_edad_z"
# [87] "ratio_mprestamos_personales_sobre_mpasivos_margen_z"
# [88] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z"
# [89] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z"
# [90] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z"
# [91] "ratio_Visa_mpagominimo_sobre_cliente_edad_z"
# [92] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z"
# [93] "ratio_cliente_edad_sobre_mpasivos_margen_z"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria", "clase01", "azar")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 453
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"
#  [18] "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"
#  [20] "cpayroll_trx"
#  [21] "mpayroll"
#  [22] "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"
#  [24] "chomebanking_transacciones"
#  [25] "ctrx_quarter"
#  [26] "Master_status"
#  [27] "Master_fechaalta"
#  [28] "Master_mpagominimo"
#  [29] "Visa_status"
#  [30] "Visa_fechaalta"
#  [31] "Visa_mpagominimo"
#  [32] "clase_ternaria"
#  [33] "kmes"
#  [34] "mpayroll_sobre_edad"
#  [35] "flag_tiene_cpayroll_trx"
#  [36] "flag_tiene_mcuenta_corriente"
#  [37] "flag_tiene_mprestamos_personales"
#  [38] "flag_tiene_Visa_mpagominimo"
#  [39] "z_ctrx_quarter"
#  [40] "z_mcaja_ahorro"
#  [41] "z_cpayroll_trx"
#  [42] "z_mcuentas_saldo"
#  [43] "z_mcuenta_corriente"
#  [44] "z_mprestamos_personales"
#  [45] "z_mtarjeta_visa_consumo"
#  [46] "z_Visa_mpagominimo"
#  [47] "z_cliente_edad"
#  [48] "z_mpasivos_margen"
#  [49] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z"
#  [50] "ratio_ctrx_quarter_sobre_cpayroll_trx_z"
#  [51] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z"
#  [52] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z"
#  [53] "ratio_ctrx_quarter_sobre_mprestamos_personales_z"
#  [54] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z"
#  [55] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z"
#  [56] "ratio_ctrx_quarter_sobre_cliente_edad_z"
#  [57] "ratio_ctrx_quarter_sobre_mpasivos_margen_z"
#  [58] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z"
#  [59] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z"
#  [60] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z"
#  [61] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z"
#  [62] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z"
#  [63] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z"
#  [64] "ratio_mcaja_ahorro_sobre_cliente_edad_z"
#  [65] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z"
#  [66] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z"
#  [67] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z"
#  [68] "ratio_cpayroll_trx_sobre_mprestamos_personales_z"
#  [69] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z"
#  [70] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z"
#  [71] "ratio_cpayroll_trx_sobre_cliente_edad_z"
#  [72] "ratio_cpayroll_trx_sobre_mpasivos_margen_z"
#  [73] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z"
#  [74] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z"
#  [75] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z"
#  [76] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z"
#  [77] "ratio_mcuentas_saldo_sobre_cliente_edad_z"
#  [78] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z"
#  [79] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z"
#  [80] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z"
#  [81] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z"
#  [82] "ratio_mcuenta_corriente_sobre_cliente_edad_z"
#  [83] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z"
#  [84] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z"
#  [85] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z"
#  [86] "ratio_mprestamos_personales_sobre_cliente_edad_z"
#  [87] "ratio_mprestamos_personales_sobre_mpasivos_margen_z"
#  [88] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z"
#  [89] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z"
#  [90] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z"
#  [91] "ratio_Visa_mpagominimo_sobre_cliente_edad_z"
#  [92] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z"
#  [93] "ratio_cliente_edad_sobre_mpasivos_margen_z"
#  [94] "internet_lag1"
#  [95] "cliente_edad_lag1"
#  [96] "cliente_antiguedad_lag1"
#  [97] "mrentabilidad_lag1"
#  [98] "mrentabilidad_annual_lag1"
#  [99] "mcomisiones_lag1"
# [100] "mactivos_margen_lag1"
# [101] "mpasivos_margen_lag1"
# [102] "cproductos_lag1"
# [103] "mcuenta_corriente_lag1"
# [104] "mcaja_ahorro_lag1"
# [105] "cdescubierto_preacordado_lag1"
# [106] "mcuentas_saldo_lag1"
# [107] "ctarjeta_visa_transacciones_lag1"
# [108] "mtarjeta_visa_consumo_lag1"
# [109] "mtarjeta_master_consumo_lag1"
# [110] "mprestamos_personales_lag1"
# [111] "cpayroll_trx_lag1"
# [112] "mpayroll_lag1"
# [113] "ccomisiones_mantenimiento_lag1"
# [114] "ccallcenter_transacciones_lag1"
# [115] "chomebanking_transacciones_lag1"
# [116] "ctrx_quarter_lag1"
# [117] "Master_status_lag1"
# [118] "Master_fechaalta_lag1"
# [119] "Master_mpagominimo_lag1"
# [120] "Visa_status_lag1"
# [121] "Visa_fechaalta_lag1"
# [122] "Visa_mpagominimo_lag1"
# [123] "kmes_lag1"
# [124] "mpayroll_sobre_edad_lag1"
# [125] "flag_tiene_cpayroll_trx_lag1"
# [126] "flag_tiene_mcuenta_corriente_lag1"
# [127] "flag_tiene_mprestamos_personales_lag1"
# [128] "flag_tiene_Visa_mpagominimo_lag1"
# [129] "z_ctrx_quarter_lag1"
# [130] "z_mcaja_ahorro_lag1"
# [131] "z_cpayroll_trx_lag1"
# [132] "z_mcuentas_saldo_lag1"
# [133] "z_mcuenta_corriente_lag1"
# [134] "z_mprestamos_personales_lag1"
# [135] "z_mtarjeta_visa_consumo_lag1"
# [136] "z_Visa_mpagominimo_lag1"
# [137] "z_cliente_edad_lag1"
# [138] "z_mpasivos_margen_lag1"
# [139] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_lag1"
# [140] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_lag1"
# [141] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_lag1"
# [142] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_lag1"
# [143] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_lag1"
# [144] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_lag1"
# [145] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_lag1"
# [146] "ratio_ctrx_quarter_sobre_cliente_edad_z_lag1"
# [147] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_lag1"
# [148] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_lag1"
# [149] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_lag1"
# [150] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_lag1"
# [151] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_lag1"
# [152] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_lag1"
# [153] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_lag1"
# [154] "ratio_mcaja_ahorro_sobre_cliente_edad_z_lag1"
# [155] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_lag1"
# [156] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_lag1"
# [157] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_lag1"
# [158] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_lag1"
# [159] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_lag1"
# [160] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_lag1"
# [161] "ratio_cpayroll_trx_sobre_cliente_edad_z_lag1"
# [162] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_lag1"
# [163] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_lag1"
# [164] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_lag1"
# [165] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_lag1"
# [166] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_lag1"
# [167] "ratio_mcuentas_saldo_sobre_cliente_edad_z_lag1"
# [168] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_lag1"
# [169] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_lag1"
# [170] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_lag1"
# [171] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_lag1"
# [172] "ratio_mcuenta_corriente_sobre_cliente_edad_z_lag1"
# [173] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_lag1"
# [174] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_lag1"
# [175] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_lag1"
# [176] "ratio_mprestamos_personales_sobre_cliente_edad_z_lag1"
# [177] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_lag1"
# [178] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_lag1"
# [179] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_lag1"
# [180] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_lag1"
# [181] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_lag1"
# [182] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_lag1"
# [183] "ratio_cliente_edad_sobre_mpasivos_margen_z_lag1"
# [184] "internet_lag2"
# [185] "cliente_edad_lag2"
# [186] "cliente_antiguedad_lag2"
# [187] "mrentabilidad_lag2"
# [188] "mrentabilidad_annual_lag2"
# [189] "mcomisiones_lag2"
# [190] "mactivos_margen_lag2"
# [191] "mpasivos_margen_lag2"
# [192] "cproductos_lag2"
# [193] "mcuenta_corriente_lag2"
# [194] "mcaja_ahorro_lag2"
# [195] "cdescubierto_preacordado_lag2"
# [196] "mcuentas_saldo_lag2"
# [197] "ctarjeta_visa_transacciones_lag2"
# [198] "mtarjeta_visa_consumo_lag2"
# [199] "mtarjeta_master_consumo_lag2"
# [200] "mprestamos_personales_lag2"
# [201] "cpayroll_trx_lag2"
# [202] "mpayroll_lag2"
# [203] "ccomisiones_mantenimiento_lag2"
# [204] "ccallcenter_transacciones_lag2"
# [205] "chomebanking_transacciones_lag2"
# [206] "ctrx_quarter_lag2"
# [207] "Master_status_lag2"
# [208] "Master_fechaalta_lag2"
# [209] "Master_mpagominimo_lag2"
# [210] "Visa_status_lag2"
# [211] "Visa_fechaalta_lag2"
# [212] "Visa_mpagominimo_lag2"
# [213] "kmes_lag2"
# [214] "mpayroll_sobre_edad_lag2"
# [215] "flag_tiene_cpayroll_trx_lag2"
# [216] "flag_tiene_mcuenta_corriente_lag2"
# [217] "flag_tiene_mprestamos_personales_lag2"
# [218] "flag_tiene_Visa_mpagominimo_lag2"
# [219] "z_ctrx_quarter_lag2"
# [220] "z_mcaja_ahorro_lag2"
# [221] "z_cpayroll_trx_lag2"
# [222] "z_mcuentas_saldo_lag2"
# [223] "z_mcuenta_corriente_lag2"
# [224] "z_mprestamos_personales_lag2"
# [225] "z_mtarjeta_visa_consumo_lag2"
# [226] "z_Visa_mpagominimo_lag2"
# [227] "z_cliente_edad_lag2"
# [228] "z_mpasivos_margen_lag2"
# [229] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_lag2"
# [230] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_lag2"
# [231] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_lag2"
# [232] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_lag2"
# [233] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_lag2"
# [234] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_lag2"
# [235] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_lag2"
# [236] "ratio_ctrx_quarter_sobre_cliente_edad_z_lag2"
# [237] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_lag2"
# [238] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_lag2"
# [239] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_lag2"
# [240] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_lag2"
# [241] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_lag2"
# [242] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_lag2"
# [243] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_lag2"
# [244] "ratio_mcaja_ahorro_sobre_cliente_edad_z_lag2"
# [245] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_lag2"
# [246] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_lag2"
# [247] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_lag2"
# [248] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_lag2"
# [249] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_lag2"
# [250] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_lag2"
# [251] "ratio_cpayroll_trx_sobre_cliente_edad_z_lag2"
# [252] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_lag2"
# [253] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_lag2"
# [254] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_lag2"
# [255] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_lag2"
# [256] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_lag2"
# [257] "ratio_mcuentas_saldo_sobre_cliente_edad_z_lag2"
# [258] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_lag2"
# [259] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_lag2"
# [260] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_lag2"
# [261] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_lag2"
# [262] "ratio_mcuenta_corriente_sobre_cliente_edad_z_lag2"
# [263] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_lag2"
# [264] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_lag2"
# [265] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_lag2"
# [266] "ratio_mprestamos_personales_sobre_cliente_edad_z_lag2"
# [267] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_lag2"
# [268] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_lag2"
# [269] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_lag2"
# [270] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_lag2"
# [271] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_lag2"
# [272] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_lag2"
# [273] "ratio_cliente_edad_sobre_mpasivos_margen_z_lag2"
# [274] "internet_delta1"
# [275] "internet_delta2"
# [276] "cliente_edad_delta1"
# [277] "cliente_edad_delta2"
# [278] "cliente_antiguedad_delta1"
# [279] "cliente_antiguedad_delta2"
# [280] "mrentabilidad_delta1"
# [281] "mrentabilidad_delta2"
# [282] "mrentabilidad_annual_delta1"
# [283] "mrentabilidad_annual_delta2"
# [284] "mcomisiones_delta1"
# [285] "mcomisiones_delta2"
# [286] "mactivos_margen_delta1"
# [287] "mactivos_margen_delta2"
# [288] "mpasivos_margen_delta1"
# [289] "mpasivos_margen_delta2"
# [290] "cproductos_delta1"
# [291] "cproductos_delta2"
# [292] "mcuenta_corriente_delta1"
# [293] "mcuenta_corriente_delta2"
# [294] "mcaja_ahorro_delta1"
# [295] "mcaja_ahorro_delta2"
# [296] "cdescubierto_preacordado_delta1"
# [297] "cdescubierto_preacordado_delta2"
# [298] "mcuentas_saldo_delta1"
# [299] "mcuentas_saldo_delta2"
# [300] "ctarjeta_visa_transacciones_delta1"
# [301] "ctarjeta_visa_transacciones_delta2"
# [302] "mtarjeta_visa_consumo_delta1"
# [303] "mtarjeta_visa_consumo_delta2"
# [304] "mtarjeta_master_consumo_delta1"
# [305] "mtarjeta_master_consumo_delta2"
# [306] "mprestamos_personales_delta1"
# [307] "mprestamos_personales_delta2"
# [308] "cpayroll_trx_delta1"
# [309] "cpayroll_trx_delta2"
# [310] "mpayroll_delta1"
# [311] "mpayroll_delta2"
# [312] "ccomisiones_mantenimiento_delta1"
# [313] "ccomisiones_mantenimiento_delta2"
# [314] "ccallcenter_transacciones_delta1"
# [315] "ccallcenter_transacciones_delta2"
# [316] "chomebanking_transacciones_delta1"
# [317] "chomebanking_transacciones_delta2"
# [318] "ctrx_quarter_delta1"
# [319] "ctrx_quarter_delta2"
# [320] "Master_status_delta1"
# [321] "Master_status_delta2"
# [322] "Master_fechaalta_delta1"
# [323] "Master_fechaalta_delta2"
# [324] "Master_mpagominimo_delta1"
# [325] "Master_mpagominimo_delta2"
# [326] "Visa_status_delta1"
# [327] "Visa_status_delta2"
# [328] "Visa_fechaalta_delta1"
# [329] "Visa_fechaalta_delta2"
# [330] "Visa_mpagominimo_delta1"
# [331] "Visa_mpagominimo_delta2"
# [332] "kmes_delta1"
# [333] "kmes_delta2"
# [334] "mpayroll_sobre_edad_delta1"
# [335] "mpayroll_sobre_edad_delta2"
# [336] "flag_tiene_cpayroll_trx_delta1"
# [337] "flag_tiene_cpayroll_trx_delta2"
# [338] "flag_tiene_mcuenta_corriente_delta1"
# [339] "flag_tiene_mcuenta_corriente_delta2"
# [340] "flag_tiene_mprestamos_personales_delta1"
# [341] "flag_tiene_mprestamos_personales_delta2"
# [342] "flag_tiene_Visa_mpagominimo_delta1"
# [343] "flag_tiene_Visa_mpagominimo_delta2"
# [344] "z_ctrx_quarter_delta1"
# [345] "z_ctrx_quarter_delta2"
# [346] "z_mcaja_ahorro_delta1"
# [347] "z_mcaja_ahorro_delta2"
# [348] "z_cpayroll_trx_delta1"
# [349] "z_cpayroll_trx_delta2"
# [350] "z_mcuentas_saldo_delta1"
# [351] "z_mcuentas_saldo_delta2"
# [352] "z_mcuenta_corriente_delta1"
# [353] "z_mcuenta_corriente_delta2"
# [354] "z_mprestamos_personales_delta1"
# [355] "z_mprestamos_personales_delta2"
# [356] "z_mtarjeta_visa_consumo_delta1"
# [357] "z_mtarjeta_visa_consumo_delta2"
# [358] "z_Visa_mpagominimo_delta1"
# [359] "z_Visa_mpagominimo_delta2"
# [360] "z_cliente_edad_delta1"
# [361] "z_cliente_edad_delta2"
# [362] "z_mpasivos_margen_delta1"
# [363] "z_mpasivos_margen_delta2"
# [364] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_delta1"
# [365] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_delta2"
# [366] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_delta1"
# [367] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_delta2"
# [368] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_delta1"
# [369] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_delta2"
# [370] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_delta1"
# [371] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_delta2"
# [372] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_delta1"
# [373] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_delta2"
# [374] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_delta1"
# [375] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_delta2"
# [376] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_delta1"
# [377] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_delta2"
# [378] "ratio_ctrx_quarter_sobre_cliente_edad_z_delta1"
# [379] "ratio_ctrx_quarter_sobre_cliente_edad_z_delta2"
# [380] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_delta1"
# [381] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_delta2"
# [382] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_delta1"
# [383] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_delta2"
# [384] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_delta1"
# [385] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_delta2"
# [386] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_delta1"
# [387] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_delta2"
# [388] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_delta1"
# [389] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_delta2"
# [390] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_delta1"
# [391] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_delta2"
# [392] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_delta1"
# [393] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_delta2"
# [394] "ratio_mcaja_ahorro_sobre_cliente_edad_z_delta1"
# [395] "ratio_mcaja_ahorro_sobre_cliente_edad_z_delta2"
# [396] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_delta1"
# [397] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_delta2"
# [398] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_delta1"
# [399] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_delta2"
# [400] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_delta1"
# [401] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_delta2"
# [402] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_delta1"
# [403] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_delta2"
# [404] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_delta1"
# [405] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_delta2"
# [406] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_delta1"
# [407] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_delta2"
# [408] "ratio_cpayroll_trx_sobre_cliente_edad_z_delta1"
# [409] "ratio_cpayroll_trx_sobre_cliente_edad_z_delta2"
# [410] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_delta1"
# [411] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_delta2"
# [412] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_delta1"
# [413] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_delta2"
# [414] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_delta1"
# [415] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_delta2"
# [416] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_delta1"
# [417] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_delta2"
# [418] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_delta1"
# [419] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_delta2"
# [420] "ratio_mcuentas_saldo_sobre_cliente_edad_z_delta1"
# [421] "ratio_mcuentas_saldo_sobre_cliente_edad_z_delta2"
# [422] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_delta1"
# [423] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_delta2"
# [424] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_delta1"
# [425] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_delta2"
# [426] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_delta1"
# [427] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_delta2"
# [428] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_delta1"
# [429] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_delta2"
# [430] "ratio_mcuenta_corriente_sobre_cliente_edad_z_delta1"
# [431] "ratio_mcuenta_corriente_sobre_cliente_edad_z_delta2"
# [432] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_delta1"
# [433] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_delta2"
# [434] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_delta1"
# [435] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_delta2"
# [436] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_delta1"
# [437] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_delta2"
# [438] "ratio_mprestamos_personales_sobre_cliente_edad_z_delta1"
# [439] "ratio_mprestamos_personales_sobre_cliente_edad_z_delta2"
# [440] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_delta1"
# [441] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_delta2"
# [442] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_delta1"
# [443] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_delta2"
# [444] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_delta1"
# [445] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_delta2"
# [446] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_delta1"
# [447] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_delta2"
# [448] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_delta1"
# [449] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_delta2"
# [450] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_delta1"
# [451] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_delta2"
# [452] "ratio_cliente_edad_sobre_mpasivos_margen_z_delta1"
# [453] "ratio_cliente_edad_sobre_mpasivos_margen_z_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset reducido de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %% [markdown]
# Esta celda tarda en correr interminables 7 minutos en Colab
# <br> ya que debe instalar la librería de LightGBM

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 13202

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en el Grid Search
#   * num_leaves  [64, 512]
#   * min_data_in_leaf  [64, 2048]

# %%
# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.03,
  feature_fraction= 0.5,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200,
  num_leaves= 64,
  min_data_in_leaf= 128
)

# %%
# En  x llegan los parametros moviles de LightGBM
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " niter ", modelo_train$best_iter,
    " AUC ", AUC
  )

  niter <- modelo_train$best_iter
  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return( list(AUC, niter))
}

# %% [markdown]
# seteo del Grid Search

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
tb_nueva <- CJ(
  num_leaves= c(64, 128, 256, 512),
  min_data_in_leaf= c(64, 256, 512, 1024, 2048)
)

# %% [markdown]
# Corrida del Grid Search,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
# <br> ATENCION, la siguiente celda demora 50 minutos en Colab
# <br> lamento profundamente tal intolerable espera gerencial

# %%
# registro a registro calculo la AUC
tb_nueva[, c("AUC", "num_iterations"):= Estimar_AUC_lightgbm( .SD ),
  by=1:nrow(tb_nueva) ]
# Out:
# Sun Sep 20 11:50:32 PM 2026  64, 64 niter 204 AUC 0.945185811726688
#
# Sun Sep 20 11:51:54 PM 2026  64, 256 niter 405 AUC 0.94481494735244
#
# Sun Sep 20 11:53:05 PM 2026  64, 512 niter 307 AUC 0.946319659065031
#
# Sun Sep 20 11:54:37 PM 2026  64, 1024 niter 434 AUC 0.942873006061789
#
# Sun Sep 20 11:56:12 PM 2026  64, 2048 niter 572 AUC 0.941136233015604
#
# Sun Sep 20 11:57:37 PM 2026  128, 64 niter 323 AUC 0.947638721710747
#
# Mon Sep 21 12:00:17 AM 2026  128, 256 niter 760 AUC 0.945288178969171
#
# Mon Sep 21 12:02:18 AM 2026  128, 512 niter 445 AUC 0.945022284394417
#
# Mon Sep 21 12:03:44 AM 2026  128, 1024 niter 349 AUC 0.94437988657189
#
# Mon Sep 21 12:05:17 AM 2026  128, 2048 niter 572 AUC 0.941136233015604
#
# Mon Sep 21 12:07:19 AM 2026  256, 64 niter 401 AUC 0.948936096381361
#
# Mon Sep 21 12:08:42 AM 2026  256, 256 niter 206 AUC 0.943184879143759
#
# Mon Sep 21 12:10:18 AM 2026  256, 512 niter 363 AUC 0.94388756953707
#
# Mon Sep 21 12:11:35 AM 2026  256, 1024 niter 349 AUC 0.94437988657189
#
# Mon Sep 21 12:13:09 AM 2026  256, 2048 niter 572 AUC 0.941136233015604
#
# Mon Sep 21 12:16:06 AM 2026  512, 64 niter 566 AUC 0.947764078206838
#
# Mon Sep 21 12:18:54 AM 2026  512, 256 niter 557 AUC 0.945307698146763
#
# Mon Sep 21 12:20:29 AM 2026  512, 512 niter 363 AUC 0.94388756953707
#
# Mon Sep 21 12:21:47 AM 2026  512, 1024 niter 349 AUC 0.94437988657189
#
# Mon Sep 21 12:23:20 AM 2026  512, 2048 niter 572 AUC 0.941136233015604

# %% [markdown]
# la optimizacion de hiperparámetros de tipo  Grid Search ha corrido, extraigo los mejores hiperparametros

# %%
tb_nueva

fwrite( tb_nueva,
  file= "tb_grid_search_01.txt",
  sep="\t",
  append= TRUE
)
# Out:
#    num_leaves min_data_in_leaf AUC       num_iterations
# 1   64          64             0.9451858 204
# 2   64         256             0.9448149 405
# 3   64         512             0.9463197 307
# 4   64        1024             0.9428730 434
# 5   64        2048             0.9411362 572
# 6  128          64             0.9476387 323
# 7  128         256             0.9452882 760
# 8  128         512             0.9450223 445
# 9  128        1024             0.9443799 349
# 10 128        2048             0.9411362 572
# 11 256          64             0.9489361 401
# 12 256         256             0.9431849 206
# 13 256         512             0.9438876 363
# 14 256        1024             0.9443799 349
# 15 256        2048             0.9411362 572
# 16 512          64             0.9477641 566
# 17 512         256             0.9453077 557
# 18 512         512             0.9438876 363
# 19 512        1024             0.9443799 349
# 20 512        2048             0.9411362 572

# %%
setorder( tb_nueva, -AUC)  # ordeno DESCENDENTE por AUC
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC] # en la posicion 1 estan los mejores
PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros
# Out:
# $num_leaves
# [1] 256
#
# $min_data_in_leaf
# [1] 64
#
# $num_iterations
# [1] 401

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en optimización de hiperparámetros

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 91832

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "utn-2026-virtual-mgr"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  Sys.sleep(30)
  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Sep 21 12:30:36 AM 2026"

# %%
require("data.table")

PARAM <- list()
PARAM$experimento <- "ENS_6300_6302"
PARAM$kaggle <- list()
PARAM$kaggle$competencia <- "utn-2026-virtual-mgr"
PARAM$kaggle$cortes <- seq(600, 1200, by = 50)   # ajustá a tu límite diario de envíos

# 1) leo las predicciones de los dos experimentos (revisá las rutas con ls)
archivos <- c(
  "buckets/b1/exp/WF6300/prediccion.txt",
  "buckets/b1/exp/WF6302/prediccion.txt"
)
tb_todas <- rbindlist(lapply(archivos, fread))

# 2) ensemble: promedio de probabilidad por cliente
tb_prediccion <- tb_todas[, list(prob = mean(prob)), by = numero_de_cliente]
setorder(tb_prediccion, -prob)

# 3) mismo bucle que el profe
dir.create("kaggle", showWarnings = FALSE)

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L]
  tb_prediccion[1:envios, Predicted := 1L]

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle, sep = ","
  )

  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste("-f", archivo_kaggle)
  mensaje <- paste0("-m 'ensemble 6300+6302 envios=", envios, "'")

  linea <- paste(comando, competencia, arch, mensaje)

  Sys.sleep(30)
  salida <- system(linea, intern = TRUE)
  cat(salida, "\n")
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 virtual mgr
